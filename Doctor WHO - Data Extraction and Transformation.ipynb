# %% [markdown]
# # Scraping Doctor Who Episodes

# %% [markdown]
# ## Introduction
# The following program scrapes the list of  **Doctor Who seasons and episodes ([1963-1989](https://en.wikipedia.org/wiki/List_of_Doctor_Who_episodes_(1963%E2%80%931989)), [2005-Present](https://en.wikipedia.org/wiki/List_of_Doctor_Who_episodes_(2005%E2%80%93present)))** from Wikipedia page.

# %% [markdown]
# ## Table of Contents
# 1. Import Primary Modules
# 2. Scraping 1963-1989 episodes
# 3. Dataframe Transformation (1963-1989)
# 4. Scraping 2005-Present episodes
# 5. Dataframe Transformation (2005-Present)
# 6. Combining both Dataframes

# %% [markdown]
# ### About dataset

# %% [markdown]
# The dataset that will be scraped from webpage contains 861 records of broadcasted Dr.Who episodes and specials from both Classical and Revival Era. It includes following fields:
#
# | Field          | Description                                                                                  |
# |----------------|----------------------------------------------------------------------------------------------|
# | Story          | The story number not official designations of episodes but rough guide of story arc          |
# | Serial         | Numeric classifier of plots in  sequential episode-by-episode fashion                        |
# | Episode        | Numeric classifier of an episode in a season or series                                       |
# | Serial title   | The main title of the serial                                                                 |
# | Episode titles | The title of an epidsode                                                                     |
# | Directed by    | A person who directed the main production                                                    |
# | Written by     | A person or people who wrote the story or plot                                               |
# | Prod.code      | An alphanumeric designation used to  identify episodes within a television series            |
# | UK viewers(M)  | The number of viewers in the UK(United Kingdom) in millions                                  |
# | AI             | A score out of 100 which is used as an indicator of the public's appreciation of TV series   |

# %% [markdown]
# ## Importing Primary Modules

# %% [markdown]
# The program heavily relies on [*pandas*](http://pandas.pydata.org/) and [**Numpy**](http://www.numpy.org/) for data wrangling and transformation.
#
# Given that website contains multiple tables and complicated syntax, for faster and efficient scraping
# **`pd.read_html`** will be used instead of **`BeautifulSoul.`**

# %%
import pandas as pd
import requests
import csv
import numpy as np

# %% [markdown]
# ## Scraping 1963-1989 episodes.
# ### Data Extraction

# %% [markdown]
# Define url where the data is located.

# %%
url = 'https://en.wikipedia.org/wiki/List_of_Doctor_Who_episodes_(1963%E2%80%931989)'

# %% [markdown]
# Using **for loop** all the tables will be scraped into consequtive dataframes starting with **dfc_** and **#** of the table, whereas **"c"** stands for seasons from **_Classical Era_**. There are a total of **26** seasons however, after thorough analysis of webpage it is identified that an index of episode table starts with **2 and ends with 29** thus giving the **range(2,30)***.
#
# *We use 30 to cover all 29 tables with episodes.

# %%
for c in range(2,30):
     exec('dfc_{} = pd.read_html(url,header=0)[{}]'.format(c,c))

# %% [markdown]
# To reduce the number of lines and calls of repetitive code, all dataframes will be merged using **pd.concat** under **df_clas**.

# %%
pdList = []
pdList.extend(value for name, value in locals().items() 
              if name.startswith('dfc_'))
df_clas = pd.concat(pdList, ignore_index=True)

# %% [markdown]
# ## Dataframe Transformation/ Cleaning.

# %% [markdown]
# Dataset information prior to changes.

# %%
df_clas
# Out:
#     Story Serial        Serial title        Episode titles    Directed by  \
# 0       1      1  An Unearthly Child  "An Unearthly Child"  Waris Hussein
# 1       1      1  An Unearthly Child  "The Cave of Skulls"  Waris Hussein
# 2       1      1  An Unearthly Child  "The Forest of Fear"  Waris Hussein
# 3       1      1  An Unearthly Child       "The Firemaker"  Waris Hussein
# 4     NaN    NaN                 NaN                   NaN            NaN
# ..    ...    ...                 ...                   ...            ...
# 851   NaN    NaN                 NaN                   NaN            NaN
# 852   155      4            Survival            "Part One"   Alan Wareing
# 853   155      4            Survival            "Part Two"   Alan Wareing
# 854   155      4            Survival          "Part Three"   Alan Wareing
# 855   NaN    NaN                 NaN                   NaN            NaN
#
#                                        Written by Original air date Prod.code  \
# 0    Anthony Coburn and C. E. Webber (uncredited)  23 November 1963         A
# 1                                  Anthony Coburn  30 November 1963         A
# 2                                  Anthony Coburn   7 December 1963         A
# 3                                  Anthony Coburn  14 December 1963         A
# 4                                             NaN               NaN       NaN
# ..                                            ...               ...       ...
# 851                                           NaN               NaN       NaN
# 852                                    Rona Munro  22 November 1989        7P
# 853                                    Rona Munro  29 November 1989        7P
# 854                                    Rona Munro   6 December 1989        7P
# 855                                           NaN               NaN       NaN
#
#     UK viewers(millions) [7] AI [7] Unnamed: 10 Unnamed: 11 Unnamed: 12
# 0                        4.4     63         NaN         NaN         NaN
# 1                        5.9     59         NaN         NaN         NaN
# 2                        6.9     56         NaN         NaN         NaN
# 3                        6.4     55         NaN         NaN         NaN
# 4                        NaN    NaN         NaN         NaN         NaN
# ..                       ...    ...         ...         ...         ...
# 851                      NaN    NaN         NaN         NaN         NaN
# 852                        5     69         NaN         NaN         NaN
# 853                      4.8     69         NaN         NaN         NaN
# 854                        5     71         NaN         NaN         NaN
# 855                      NaN    NaN         NaN         NaN         NaN
#
# [856 rows x 13 columns]

# %%
df_clas.dtypes
# Out:
# Story                       object
# Serial                      object
# Serial title                object
# Episode titles              object
# Directed by                 object
# Written by                  object
# Original air date           object
# Prod.code                   object
# UK viewers(millions) [7]    object
# AI [7]                      object
# Unnamed: 10                 object
# Unnamed: 11                 object
# Unnamed: 12                 object
# dtype: object

# %%
df_clas.shape
# Out:
# (856, 13)

# %% [markdown]
# ### Changing Columns and Rows Attributes

# %% [markdown]
# #### Removing rows and columns

# %%
#Removing Nah and Special rows
df_clas=df_clas.dropna(axis='rows',subset=['Serial title'])
df_clas.drop(df_clas[df_clas['Serial title'] == 'Special'].index, inplace = True) 

#Removing Unnamed Columns
df_clas.drop(columns=['Unnamed: 10','Unnamed: 11','Unnamed: 12'],inplace = True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %% [markdown]
# The "Shada" episode removed from dataframe. Since an episode was left unfinished due to a strike but was later completed and officially released on home media in 2017.

# %%
#Removing Shada.
df_clas.drop(df_clas[df_clas['Serial title'] == 'Shada'].index, inplace = True)

# %% [markdown]
# #### Renaming rows and columns

# %%
#Renaming UK viewers(millions) and AI columns by dropping [7] 
df_clas=df_clas.rename(columns={'UK viewers(millions) [7]':'UK viewers(millions)',
                           'AI [7]': 'AI'})

#Renaming Rows Attributes
df_clas=df_clas.replace({"[Episode 3][note 1]":"\"Episode 3\""})
df_clas=df_clas.replace(["143a","143b","143c","143d"],143)
df_clas['Original air date'] = df_clas['Original air date'].str.strip('[a]')
df_clas=df_clas.replace(['—','–'],None)

# %% [markdown]
# #### Changing datatype

# %%
df_clas=df_clas.convert_dtypes()

# %%
df_clas.dtypes
# Out:
# Story                   object
# Serial                  object
# Serial title            string
# Episode titles          string
# Directed by             string
# Written by              string
# Original air date       string
# Prod.code               string
# UK viewers(millions)    object
# AI                      object
# dtype: object

# %%
df_clas['Story'] = df_clas['Story'].astype('int64') 
df_clas['Serial'] = df_clas['Serial'].astype('int64') 
df_clas['UK viewers(millions)'] = df_clas['UK viewers(millions)'].astype('float') 
df_clas['AI'] = df_clas['AI'].astype('int64')
df_clas['Original air date']= pd.to_datetime(df_clas['Original air date'])

# %%
df_clas.dtypes
# Out:
# Story                            int64
# Serial                           int64
# Serial title                    string
# Episode titles                  string
# Directed by                     string
# Written by                      string
# Original air date       datetime64[ns]
# Prod.code                       string
# UK viewers(millions)           float64
# AI                               int64
# dtype: object

# %% [markdown]
# ### Additional Changes

# %% [markdown]
# #### Addining Episode#, Season #, Doctor #,  and Lead Actor

# %%
conditions=[df_clas['Story'].between(1,8),df_clas['Story'].between(9,17),
            df_clas['Story'].between(18,27),df_clas['Story'].between(28,36),
            df_clas['Story'].between(37,43),df_clas['Story'].between(44,50),
            df_clas['Story'].between(51,54),df_clas['Story'].between(55,59),
            df_clas['Story'].between(60,64),df_clas['Story'].between(65,69),
            df_clas['Story'].between(70,74),df_clas['Story'].between(75,79),
            df_clas['Story'].between(80,85),df_clas['Story'].between(86,91),
            df_clas['Story'].between(92,97),df_clas['Story'].between(98,103),
            df_clas['Story'].between(104,108),df_clas['Story'].between(109,115),
            df_clas['Story'].between(116,122),df_clas['Story'].between(123,129),
            df_clas['Story'].between(130,136),df_clas['Story'].between(137,142),
            df_clas['Story'].between(143,143),df_clas['Story'].between(144,147),
            df_clas['Story'].between(148,151),df_clas['Story'].between(152,155)]

choices = []
for n in range(1,27):
    choices.append(n)

df_clas['Season'] = np.select(conditions,choices)

# %%
cond=[df_clas['Season'].between(1,3),df_clas['Season'].between(4,6),
      df_clas['Season'].between(7,11),df_clas['Season'].between(12,18),
      df_clas['Season'].between(19,21),df_clas['Season'].between(22,23),
      df_clas['Season'].between(24,26)]

doctor = ['First Doctor','Second Doctor','Third Doctor',
          'Fourth Doctor','Fifth Doctor','Sixth Doctor','Seventh Doctor']
actor = ['William Hartnell','Patrick Troughton','Jon Pertwee',
         'Tom Baker','Peter Davison','Colin Baker','Sylvester McCoy']
df_clas['Doctor'] = np.select(cond,doctor)
df_clas['Lead Actor'] = np.select(cond,actor)

# %% [markdown]
# Addding **Episode** column to dataframe.

# %%
episodes = []
for s in range(1,df_clas['Season'].nunique()+1):
    n_ep = len(df_clas[df_clas['Season']==s])
    for n in range(1,n_ep+1):
        episodes.append(n)
        
df_clas['Episode'] = episodes

# %% [markdown]
# Reordering columns in a **df_class** dataframe.

# %%
column_names = ["Story", "Serial", "Episode", "Serial title",
                "Episode titles", "Directed by", "Written by",
                "Original air date", "Prod.code", "UK viewers(millions)", 
                "AI", "Season", "Doctor", "Lead Actor"]

df_clas = df_clas.reindex(columns=column_names)

# %% [markdown]
# #### End result

# %%
#Resetting Index
df_clas.index = np.arange(1,len(df_clas)+1)
df_clas
# Out:
#      Story  Serial  Episode         Serial title        Episode titles  \
# 1        1       1        1   An Unearthly Child  "An Unearthly Child"
# 2        1       1        2   An Unearthly Child  "The Cave of Skulls"
# 3        1       1        3   An Unearthly Child  "The Forest of Fear"
# 4        1       1        4   An Unearthly Child       "The Firemaker"
# 5        2       2        5           The Daleks     "The Dead Planet"
# ..     ...     ...      ...                  ...                   ...
# 691    154       3       10  The Curse of Fenric          "Part Three"
# 692    154       3       11  The Curse of Fenric           "Part Four"
# 693    155       4       12             Survival            "Part One"
# 694    155       4       13             Survival            "Part Two"
# 695    155       4       14             Survival          "Part Three"
#
#            Directed by                                    Written by  \
# 1        Waris Hussein  Anthony Coburn and C. E. Webber (uncredited)
# 2        Waris Hussein                                Anthony Coburn
# 3        Waris Hussein                                Anthony Coburn
# 4        Waris Hussein                                Anthony Coburn
# 5    Christopher Barry                                  Terry Nation
# ..                 ...                                           ...
# 691   Nicholas Mallett                                    Ian Briggs
# 692   Nicholas Mallett                                    Ian Briggs
# 693       Alan Wareing                                    Rona Munro
# 694       Alan Wareing                                    Rona Munro
# 695       Alan Wareing                                    Rona Munro
#
#     Original air date Prod.code  UK viewers(millions)  AI  Season  \
# 1          1963-11-23         A                   4.4  63       1
# 2          1963-11-30         A                   5.9  59       1
# 3          1963-12-07         A                   6.9  56       1
# 4          1963-12-14         A                   6.4  55       1
# 5          1963-12-21         B                   6.9  59       1
# ..                ...       ...                   ...  ..     ...
# 691        1989-11-08        7M                   4.0  68      26
# 692        1989-11-15        7M                   4.2  68      26
# 693        1989-11-22        7P                   5.0  69      26
# 694        1989-11-29        7P                   4.8  69      26
# 695        1989-12-06        7P                   5.0  71      26
#
#              Doctor        Lead Actor
# 1      First Doctor  William Hartnell
# 2      First Doctor  William Hartnell
# 3      First Doctor  William Hartnell
# 4      First Doctor  William Hartnell
# 5      First Doctor  William Hartnell
# ..              ...               ...
# 691  Seventh Doctor   Sylvester McCoy
# 692  Seventh Doctor   Sylvester McCoy
# 693  Seventh Doctor   Sylvester McCoy
# 694  Seventh Doctor   Sylvester McCoy
# 695  Seventh Doctor   Sylvester McCoy
#
# [695 rows x 14 columns]

# %% [markdown]
# Using **.groupby()** and **.stack()** we can check if double check the number of episodes per season.

# %%
df_clas[['Season','Episode']].groupby('Season').nunique().stack()
# Out:
# Season
# 1       Episode    42
# 2       Episode    39
# 3       Episode    45
# 4       Episode    43
# 5       Episode    40
# 6       Episode    44
# 7       Episode    25
# 8       Episode    25
# 9       Episode    26
# 10      Episode    26
# 11      Episode    26
# 12      Episode    20
# 13      Episode    26
# 14      Episode    26
# 15      Episode    26
# 16      Episode    26
# 17      Episode    20
# 18      Episode    28
# 19      Episode    26
# 20      Episode    23
# 21      Episode    24
# 22      Episode    13
# 23      Episode    14
# 24      Episode    14
# 25      Episode    14
# 26      Episode    14
# dtype: int64

# %%
df_clas.shape
# Out:
# (695, 14)

# %%
df_clas.dtypes
# Out:
# Story                            int64
# Serial                           int64
# Episode                          int64
# Serial title                    string
# Episode titles                  string
# Directed by                     string
# Written by                      string
# Original air date       datetime64[ns]
# Prod.code                       string
# UK viewers(millions)           float64
# AI                               int64
# Season                           int32
# Doctor                          object
# Lead Actor                      object
# dtype: object

# %% [markdown]
# ##### Optional: Saving dataframe as CSV  file

# %%
df_clas.to_csv("dr_who_classical.csv")

# %% [markdown]
# ## Scraping 2005-Present Episodes.
# ### Data Extraction

# %% [markdown]
# Define url of list of new episodes.

# %%
url_new = 'https://en.wikipedia.org/wiki/List_of_Doctor_Who_episodes_(2005%E2%80%93present)'

# %% [markdown]
# Considering that the tables have somewhat similar formating, the same coding and loops will be used to scrape tables into dataframes. In order prevent dataframes from rewriting existing ones, **dfr_** will be used, whereby **r** designating seasons from **_Revival Era_**. As of Feb. 2021 there are a total of **12 Seasons**, however compare to previous webpage, the seasons tables starts with an index of **3** and ending with an index of **16** thus giving the **range(3,17)**.

# %%
for c in range(3,17):
     exec('dfr_{} = pd.read_html(url_new,header=0)[{}]'.format(c,c))

# %% [markdown]
# Due to an odd change in tables column titles for the latest **Season 12** the following changes must me made to match structure of other dataframes. Thus using **.rename()** funciton columns including "No.story" and "No. inseries" renamed to "Story" and "Episode".
#
# *_Season 12_ is saved under the dataframe name _dfr_16_.

# %%
dfr_16=dfr_16.rename(columns={"No.story":"Story",'No. inseries':'Episode'})
#dfr_16

# %% [markdown]
# Merge all dataframes under the names **df_rev**.

# %%
pdList_new = []
pdList_new.extend(value for name, value in locals().items() 
              if name.startswith('dfr_'))
df_rev = pd.concat(pdList_new, ignore_index=True)

# %% [markdown]
# ## Dataframe Transformation/ Cleaning.

# %% [markdown]
# Dataset information prior to changes.

# %%
df_rev.dtypes
# Out:
# Story                       object
# Episode                     object
# Title                       object
# Directed by                 object
# Written by                  object
# Original air date           object
# Prod.code                   object
# UK viewers(millions) [9]    object
# AI [9]                      object
# Unnamed: 9                  object
# Unnamed: 10                 object
# Unnamed: 11                 object
# Unnamed: 12                 object
# Unnamed: 8                  object
# dtype: object

# %%
df_rev.shape
# Out:
# (187, 14)

# %% [markdown]
# ### Changing Columns and Rows Attributes

# %% [markdown]
# #### Removing  rows and columns

# %%
#Removing Nah rows
df_rev=df_rev.dropna(axis='rows',subset=['Title'])

#Remove Unnamed Columns
df_rev=df_rev.drop(columns=['Unnamed: 8','Unnamed: 9','Unnamed: 10','Unnamed: 11','Unnamed: 12'])

#Removing Special, Series, Part 1&2 rows.
df_rev.drop(df_rev[df_rev['Title'].str.contains("Special", na=False)].index,inplace = True)
df_rev.drop(df_rev[df_rev['Title'] == 'Series'].index, inplace = True)
df_rev.drop(df_rev[df_rev['Title'] == 'Part 1'].index, inplace = True) 
df_rev.drop(df_rev[df_rev['Title'] == 'Part 2'].index, inplace = True)

# %% [markdown]
# #### Renaming rows and columns

# %%
#Renaming UK viewers(millions) and AI columns by dropping [9] 
df_rev=df_rev.rename(columns={'UK viewers(millions) [9]':'UK viewers(millions)',
                              'AI [9]': 'AI'})

#Replacing Story variable index with with ''
df_rev['Story']=df_rev['Story'].str.replace('a', '')
df_rev['Story']=df_rev['Story'].str.replace('b', '')
df_rev['Story']=df_rev['Story'].str.replace('c', '')
df_rev['Story']=df_rev['Story'].str.replace('†', '(missing)')

#Renaming Rows Attributes
df_rev['Prod.code']=df_rev['Prod.code'].fillna('None')
df_rev=df_rev.replace(['—','–'],None)

#Adding Missing indexes to a Story and Ep column
df_rev.loc[df_rev['Title'] == '"The Day of the Doctor"', ['Story']] = '240'
df_rev.loc[df_rev['Title'] == '"The Time of the Doctor"', ['Story']] = '241'

# %% [markdown]
# #### Changing datatype

# %%
df_rev=df_rev.convert_dtypes()

# %%
df_rev.dtypes
# Out:
# Story                   string
# Episode                 object
# Title                   string
# Directed by             string
# Written by              string
# Original air date       string
# Prod.code               object
# UK viewers(millions)    object
# AI                      object
# dtype: object

# %%
df_rev['Story'] = df_rev['Story'].astype('int')
df_rev['Episode'] = df_rev['Episode'].astype('int')
df_rev['UK viewers(millions)'] = df_rev['UK viewers(millions)'].astype('float') 
df_rev['AI'] = df_rev['AI'].astype('int')
df_rev['Prod.code'] = df_rev['Prod.code'].astype('str')
df_rev['Original air date']= pd.to_datetime(df_rev['Original air date'])

# %%
df_rev.dtypes
# Out:
# Story                            int32
# Episode                          int32
# Title                           string
# Directed by                     string
# Written by                      string
# Original air date       datetime64[ns]
# Prod.code                       object
# UK viewers(millions)           float64
# AI                               int32
# dtype: object

# %% [markdown]
# ### Additional Changes

# %% [markdown]
# #### Addining Season #, Doctor #, and Lead Actor

# %%
conditions=[df_rev['Story'].between(157,166),df_rev['Story'].between(167,177),
            df_rev['Story'].between(178,187),df_rev['Story'].between(188,202),
            df_rev['Story'].between(203,212),df_rev['Story'].between(213,224),
            df_rev['Story'].between(225,241),df_rev['Story'].between(242,252),
            df_rev['Story'].between(253,263),df_rev['Story'].between(264,276),
            df_rev['Story'].between(277,287),df_rev['Story'].between(288,296)]

choices = []
for n in range(1,13):
    choices.append(n)

df_rev['Season'] = np.select(conditions,choices)

# %%
cond=[df_rev['Season'].between(1,1),df_rev['Season'].between(2,4),
      df_rev['Season'].between(5,7),df_rev['Season'].between(8,10),
      df_rev['Season'].between(11,12)]

doctor = ['Ninth Doctor','Tenth Doctor','Eleventh Doctor',
          'Twelfth Doctor','Thirteenth Doctor']
actor = ['Christopher Eccleston','David Tennant',
         'Matt Smith','Peter Capaldi','Jodie Whittaker']

df_rev['Doctor'] = np.select(cond,doctor)
df_rev['Lead Actor'] = np.select(cond,actor)

# %% [markdown]
# #### End result

# %%
#Resetting Index
df_rev.index = np.arange(1,len(df_rev)+1)
df_rev
# Out:
#      Story  Episode                            Title         Directed by  \
# 1      157        1                           "Rose"          Keith Boak
# 2      158        2           "The End of the World"           Euros Lyn
# 3      159        3               "The Unquiet Dead"           Euros Lyn
# 4      160        4               "Aliens of London"          Keith Boak
# 5      160        5                "World War Three"          Keith Boak
# ..     ...      ...                              ...                 ...
# 162    293        7               "Can You Hear Me?"       Emma Sullivan
# 163    294        8  "The Haunting of Villa Diodati"       Emma Sullivan
# 164    295        9      "Ascension of the Cybermen"  Jamie Magnus Stone
# 165    295       10          "The Timeless Children"  Jamie Magnus Stone
# 166    296       10       "Revolution of the Daleks"     Lee Haven Jones
#
#                             Written by Original air date Prod.code  \
# 1                     Russell T Davies        2005-03-26       1.1
# 2                     Russell T Davies        2005-04-02       1.2
# 3                          Mark Gatiss        2005-04-09       1.3
# 4                     Russell T Davies        2005-04-16       1.4
# 5                     Russell T Davies        2005-04-23       1.5
# ..                                 ...               ...       ...
# 162  Charlene James and Chris Chibnall        2020-02-09      None
# 163                    Maxine Alderton        2020-02-16      None
# 164                     Chris Chibnall        2020-02-23      None
# 165                     Chris Chibnall        2020-03-01      None
# 166                     Chris Chibnall        2021-01-01      None
#
#      UK viewers(millions)  AI  Season             Doctor  \
# 1                   10.81  76       1       Ninth Doctor
# 2                    7.97  76       1       Ninth Doctor
# 3                    8.86  80       1       Ninth Doctor
# 4                    7.63  82       1       Ninth Doctor
# 5                    7.98  81       1       Ninth Doctor
# ..                    ...  ..     ...                ...
# 162                  4.90  78      12  Thirteenth Doctor
# 163                  5.07  80      12  Thirteenth Doctor
# 164                  4.99  81      12  Thirteenth Doctor
# 165                  4.69  82      12  Thirteenth Doctor
# 166                  6.35  79      12  Thirteenth Doctor
#
#                 Lead Actor
# 1    Christopher Eccleston
# 2    Christopher Eccleston
# 3    Christopher Eccleston
# 4    Christopher Eccleston
# 5    Christopher Eccleston
# ..                     ...
# 162        Jodie Whittaker
# 163        Jodie Whittaker
# 164        Jodie Whittaker
# 165        Jodie Whittaker
# 166        Jodie Whittaker
#
# [166 rows x 12 columns]

# %% [markdown]
# Using **.groupby()** and **.stack()** we can check if double check the number of episodes per season.

# %%
df_rev[['Season','Episode']].groupby('Season').nunique().stack()
# Out:
# Season
# 1       Episode    13
# 2       Episode    13
# 3       Episode    13
# 4       Episode    13
# 5       Episode    13
# 6       Episode    13
# 7       Episode    13
# 8       Episode    12
# 9       Episode    12
# 10      Episode    12
# 11      Episode    10
# 12      Episode    10
# dtype: int64

# %%
df_rev.shape
# Out:
# (166, 12)

# %%
df_rev.dtypes
# Out:
# Story                            int32
# Episode                          int32
# Title                           string
# Directed by                     string
# Written by                      string
# Original air date       datetime64[ns]
# Prod.code                       object
# UK viewers(millions)           float64
# AI                               int32
# Season                           int32
# Doctor                          object
# Lead Actor                      object
# dtype: object

# %% [markdown]
# ##### Optional: Saving dataframe as CSV  file

# %%
df_rev.to_csv("dr_who_revived.csv")

# %% [markdown]
# ## Combining Dataframes.
# The following portion will combine both dataframes from Classical and Revival Era.

# %% [markdown]
# For the following dataframe the episode title columns will be renamed to **"Episode Title"**.

# %%
df_clas.rename(columns={"Episode titles": "Episode Title"}, inplace=True)
df_rev.rename(columns={"Title":"Episode Title"},inplace=True)

# %%
dr_who = pd.concat([df_clas, df_rev], axis=0,sort=False)
dr_who
# Out:
#      Story  Serial  Episode        Serial title  \
# 1        1     1.0        1  An Unearthly Child
# 2        1     1.0        2  An Unearthly Child
# 3        1     1.0        3  An Unearthly Child
# 4        1     1.0        4  An Unearthly Child
# 5        2     2.0        5          The Daleks
# ..     ...     ...      ...                 ...
# 162    293     NaN        7                <NA>
# 163    294     NaN        8                <NA>
# 164    295     NaN        9                <NA>
# 165    295     NaN       10                <NA>
# 166    296     NaN       10                <NA>
#
#                        Episode Title         Directed by  \
# 1               "An Unearthly Child"       Waris Hussein
# 2               "The Cave of Skulls"       Waris Hussein
# 3               "The Forest of Fear"       Waris Hussein
# 4                    "The Firemaker"       Waris Hussein
# 5                  "The Dead Planet"   Christopher Barry
# ..                               ...                 ...
# 162               "Can You Hear Me?"       Emma Sullivan
# 163  "The Haunting of Villa Diodati"       Emma Sullivan
# 164      "Ascension of the Cybermen"  Jamie Magnus Stone
# 165          "The Timeless Children"  Jamie Magnus Stone
# 166       "Revolution of the Daleks"     Lee Haven Jones
#
#                                        Written by Original air date Prod.code  \
# 1    Anthony Coburn and C. E. Webber (uncredited)        1963-11-23         A
# 2                                  Anthony Coburn        1963-11-30         A
# 3                                  Anthony Coburn        1963-12-07         A
# 4                                  Anthony Coburn        1963-12-14         A
# 5                                    Terry Nation        1963-12-21         B
# ..                                            ...               ...       ...
# 162             Charlene James and Chris Chibnall        2020-02-09      None
# 163                               Maxine Alderton        2020-02-16      None
# 164                                Chris Chibnall        2020-02-23      None
# 165                                Chris Chibnall        2020-03-01      None
# 166                                Chris Chibnall        2021-01-01      None
#
#      UK viewers(millions)  AI  Season             Doctor        Lead Actor
# 1                    4.40  63       1       First Doctor  William Hartnell
# 2                    5.90  59       1       First Doctor  William Hartnell
# 3                    6.90  56       1       First Doctor  William Hartnell
# 4                    6.40  55       1       First Doctor  William Hartnell
# 5                    6.90  59       1       First Doctor  William Hartnell
# ..                    ...  ..     ...                ...               ...
# 162                  4.90  78      12  Thirteenth Doctor   Jodie Whittaker
# 163                  5.07  80      12  Thirteenth Doctor   Jodie Whittaker
# 164                  4.99  81      12  Thirteenth Doctor   Jodie Whittaker
# 165                  4.69  82      12  Thirteenth Doctor   Jodie Whittaker
# 166                  6.35  79      12  Thirteenth Doctor   Jodie Whittaker
#
# [861 rows x 14 columns]

# %%
dr_who.dtypes
# Out:
# Story                            int64
# Serial                         float64
# Episode                          int64
# Serial title                    string
# Episode Title                   string
# Directed by                     string
# Written by                      string
# Original air date       datetime64[ns]
# Prod.code                       object
# UK viewers(millions)           float64
# AI                               int64
# Season                           int32
# Doctor                          object
# Lead Actor                      object
# dtype: object

# %%
dr_who[['Season','Episode']].groupby('Season').nunique().stack()
# Out:
# Season
# 1       Episode    42
# 2       Episode    39
# 3       Episode    45
# 4       Episode    43
# 5       Episode    40
# 6       Episode    44
# 7       Episode    25
# 8       Episode    25
# 9       Episode    26
# 10      Episode    26
# 11      Episode    26
# 12      Episode    20
# 13      Episode    26
# 14      Episode    26
# 15      Episode    26
# 16      Episode    26
# 17      Episode    20
# 18      Episode    28
# 19      Episode    26
# 20      Episode    23
# 21      Episode    24
# 22      Episode    13
# 23      Episode    14
# 24      Episode    14
# 25      Episode    14
# 26      Episode    14
# dtype: int64

# %%
#Resetting Index
dr_who.index = np.arange(1,len(dr_who)+1)

# %% [markdown]
# To show all rows run the following code.

# %%
#To reset rows option run pd.reset_option("max_rows")
pd.set_option("max_rows", None)
dr_who
# Out:
#      Story  Serial  Episode                          Serial title  \
# 1        1     1.0        1                    An Unearthly Child
# 2        1     1.0        2                    An Unearthly Child
# 3        1     1.0        3                    An Unearthly Child
# 4        1     1.0        4                    An Unearthly Child
# 5        2     2.0        5                            The Daleks
# 6        2     2.0        6                            The Daleks
# 7        2     2.0        7                            The Daleks
# 8        2     2.0        8                            The Daleks
# 9        2     2.0        9                            The Daleks
# 10       2     2.0       10                            The Daleks
# 11       2     2.0       11                            The Daleks
# 12       3     3.0       12               The Edge of Destruction
# 13       3     3.0       13               The Edge of Destruction
# 14       4     4.0       14                            Marco Polo
# 15       4     4.0       15                            Marco Polo
# 16       4     4.0       16                            Marco Polo
# 17       4     4.0       17                            Marco Polo
# 18       4     4.0       18                            Marco Polo
# 19       4     4.0       19                            Marco Polo
# 20       4     4.0       20                            Marco Polo
# 21       5     5.0       21                   The Keys of Marinus
# 22       5     5.0       22                   The Keys of Marinus
# 23       5     5.0       23                   The Keys of Marinus
# 24       5     5.0       24                   The Keys of Marinus
# 25       5     5.0       25                   The Keys of Marinus
# 26       5     5.0       26                   The Keys of Marinus
# 27       6     6.0       27                            The Aztecs
# 28       6     6.0       28                            The Aztecs
# 29       6     6.0       29                            The Aztecs
# 30       6     6.0       30                            The Aztecs
# 31       7     7.0       31                        The Sensorites
# 32       7     7.0       32                        The Sensorites
# 33       7     7.0       33                        The Sensorites
# 34       7     7.0       34                        The Sensorites
# 35       7     7.0       35                        The Sensorites
# 36       7     7.0       36                        The Sensorites
# 37       8     8.0       37                   The Reign of Terror
# 38       8     8.0       38                   The Reign of Terror
# 39       8     8.0       39                   The Reign of Terror
# 40       8     8.0       40                   The Reign of Terror
# 41       8     8.0       41                   The Reign of Terror
# 42       8     8.0       42                   The Reign of Terror
# 43       9     1.0        1                      Planet of Giants
# 44       9     1.0        2                      Planet of Giants
# 45       9     1.0        3                      Planet of Giants
# 46      10     2.0        4           The Dalek Invasion of Earth
# 47      10     2.0        5           The Dalek Invasion of Earth
# 48      10     2.0        6           The Dalek Invasion of Earth
# 49      10     2.0        7           The Dalek Invasion of Earth
# 50      10     2.0        8           The Dalek Invasion of Earth
# 51      10     2.0        9           The Dalek Invasion of Earth
# 52      11     3.0       10                            The Rescue
# 53      11     3.0       11                            The Rescue
# 54      12     4.0       12                            The Romans
# 55      12     4.0       13                            The Romans
# 56      12     4.0       14                            The Romans
# 57      12     4.0       15                            The Romans
# 58      13     5.0       16                        The Web Planet
# 59      13     5.0       17                        The Web Planet
# 60      13     5.0       18                        The Web Planet
# 61      13     5.0       19                        The Web Planet
# 62      13     5.0       20                        The Web Planet
# 63      13     5.0       21                        The Web Planet
# 64      14     6.0       22                           The Crusade
# 65      14     6.0       23                           The Crusade
# 66      14     6.0       24                           The Crusade
# 67      14     6.0       25                           The Crusade
# 68      15     7.0       26                      The Space Museum
# 69      15     7.0       27                      The Space Museum
# 70      15     7.0       28                      The Space Museum
# 71      15     7.0       29                      The Space Museum
# 72      16     8.0       30                             The Chase
# 73      16     8.0       31                             The Chase
# 74      16     8.0       32                             The Chase
# 75      16     8.0       33                             The Chase
# 76      16     8.0       34                             The Chase
# 77      16     8.0       35                             The Chase
# 78      17     9.0       36                      The Time Meddler
# 79      17     9.0       37                      The Time Meddler
# 80      17     9.0       38                      The Time Meddler
# 81      17     9.0       39                      The Time Meddler
# 82      18     1.0        1                              Galaxy 4
# 83      18     1.0        2                              Galaxy 4
# 84      18     1.0        3                              Galaxy 4
# 85      18     1.0        4                              Galaxy 4
# 86      19     2.0        5             "Mission to the Unknown"†
# 87      20     3.0        6                       The Myth Makers
# 88      20     3.0        7                       The Myth Makers
# 89      20     3.0        8                       The Myth Makers
# 90      20     3.0        9                       The Myth Makers
# 91      21     4.0       10               The Daleks' Master Plan
# 92      21     4.0       11               The Daleks' Master Plan
# 93      21     4.0       12               The Daleks' Master Plan
# 94      21     4.0       13               The Daleks' Master Plan
# 95      21     4.0       14               The Daleks' Master Plan
# 96      21     4.0       15               The Daleks' Master Plan
# 97      21     4.0       16               The Daleks' Master Plan
# 98      21     4.0       17               The Daleks' Master Plan
# 99      21     4.0       18               The Daleks' Master Plan
# 100     21     4.0       19               The Daleks' Master Plan
# 101     21     4.0       20               The Daleks' Master Plan
# 102     21     4.0       21               The Daleks' Master Plan
# 103     22     5.0       22  The Massacre of St Bartholomew's Eve
# 104     22     5.0       23  The Massacre of St Bartholomew's Eve
# 105     22     5.0       24  The Massacre of St Bartholomew's Eve
# 106     22     5.0       25  The Massacre of St Bartholomew's Eve
# 107     23     6.0       26                               The Ark
# 108     23     6.0       27                               The Ark
# 109     23     6.0       28                               The Ark
# 110     23     6.0       29                               The Ark
# 111     24     7.0       30                The Celestial Toymaker
# 112     24     7.0       31                The Celestial Toymaker
# 113     24     7.0       32                The Celestial Toymaker
# 114     24     7.0       33                The Celestial Toymaker
# 115     25     8.0       34                       The Gunfighters
# 116     25     8.0       35                       The Gunfighters
# 117     25     8.0       36                       The Gunfighters
# 118     25     8.0       37                       The Gunfighters
# 119     26     9.0       38                           The Savages
# 120     26     9.0       39                           The Savages
# 121     26     9.0       40                           The Savages
# 122     26     9.0       41                           The Savages
# 123     27    10.0       42                      The War Machines
# 124     27    10.0       43                      The War Machines
# 125     27    10.0       44                      The War Machines
# 126     27    10.0       45                      The War Machines
# 127     28     1.0        1                         The Smugglers
# 128     28     1.0        2                         The Smugglers
# 129     28     1.0        3                         The Smugglers
# 130     28     1.0        4                         The Smugglers
# 131     29     2.0        5                      The Tenth Planet
# 132     29     2.0        6                      The Tenth Planet
# 133     29     2.0        7                      The Tenth Planet
# 134     29     2.0        8                      The Tenth Planet
# 135     30     3.0        9               The Power of the Daleks
# 136     30     3.0       10               The Power of the Daleks
# 137     30     3.0       11               The Power of the Daleks
# 138     30     3.0       12               The Power of the Daleks
# 139     30     3.0       13               The Power of the Daleks
# 140     30     3.0       14               The Power of the Daleks
# 141     31     4.0       15                       The Highlanders
# 142     31     4.0       16                       The Highlanders
# 143     31     4.0       17                       The Highlanders
# 144     31     4.0       18                       The Highlanders
# 145     32     5.0       19                 The Underwater Menace
# 146     32     5.0       20                 The Underwater Menace
# 147     32     5.0       21                 The Underwater Menace
# 148     32     5.0       22                 The Underwater Menace
# 149     33     6.0       23                          The Moonbase
# 150     33     6.0       24                          The Moonbase
# 151     33     6.0       25                          The Moonbase
# 152     33     6.0       26                          The Moonbase
# 153     34     7.0       27                      The Macra Terror
# 154     34     7.0       28                      The Macra Terror
# 155     34     7.0       29                      The Macra Terror
# 156     34     7.0       30                      The Macra Terror
# 157     35     8.0       31                     The Faceless Ones
# 158     35     8.0       32                     The Faceless Ones
# 159     35     8.0       33                     The Faceless Ones
# 160     35     8.0       34                     The Faceless Ones
# 161     35     8.0       35                     The Faceless Ones
# 162     35     8.0       36                     The Faceless Ones
# 163     36     9.0       37                The Evil of the Daleks
# 164     36     9.0       38                The Evil of the Daleks
# 165     36     9.0       39                The Evil of the Daleks
# 166     36     9.0       40                The Evil of the Daleks
# 167     36     9.0       41                The Evil of the Daleks
# 168     36     9.0       42                The Evil of the Daleks
# 169     36     9.0       43                The Evil of the Daleks
# 170     37     1.0        1              The Tomb of the Cybermen
# 171     37     1.0        2              The Tomb of the Cybermen
# 172     37     1.0        3              The Tomb of the Cybermen
# 173     37     1.0        4              The Tomb of the Cybermen
# 174     38     2.0        5                The Abominable Snowmen
# 175     38     2.0        6                The Abominable Snowmen
# 176     38     2.0        7                The Abominable Snowmen
# 177     38     2.0        8                The Abominable Snowmen
# 178     38     2.0        9                The Abominable Snowmen
# 179     38     2.0       10                The Abominable Snowmen
# 180     39     3.0       11                      The Ice Warriors
# 181     39     3.0       12                      The Ice Warriors
# 182     39     3.0       13                      The Ice Warriors
# 183     39     3.0       14                      The Ice Warriors
# 184     39     3.0       15                      The Ice Warriors
# 185     39     3.0       16                      The Ice Warriors
# 186     40     4.0       17                The Enemy of the World
# 187     40     4.0       18                The Enemy of the World
# 188     40     4.0       19                The Enemy of the World
# 189     40     4.0       20                The Enemy of the World
# 190     40     4.0       21                The Enemy of the World
# 191     40     4.0       22                The Enemy of the World
# 192     41     5.0       23                       The Web of Fear
# 193     41     5.0       24                       The Web of Fear
# 194     41     5.0       25                       The Web of Fear
# 195     41     5.0       26                       The Web of Fear
# 196     41     5.0       27                       The Web of Fear
# 197     41     5.0       28                       The Web of Fear
# 198     42     6.0       29                    Fury from the Deep
# 199     42     6.0       30                    Fury from the Deep
# 200     42     6.0       31                    Fury from the Deep
# 201     42     6.0       32                    Fury from the Deep
# 202     42     6.0       33                    Fury from the Deep
# 203     42     6.0       34                    Fury from the Deep
# 204     43     7.0       35                    The Wheel in Space
# 205     43     7.0       36                    The Wheel in Space
# 206     43     7.0       37                    The Wheel in Space
# 207     43     7.0       38                    The Wheel in Space
# 208     43     7.0       39                    The Wheel in Space
# 209     43     7.0       40                    The Wheel in Space
# 210     44     1.0        1                        The Dominators
# 211     44     1.0        2                        The Dominators
# 497    102     5.0       18                    The Power of Kroll
# 498    102     5.0       19                    The Power of Kroll
# 499    102     5.0       20                    The Power of Kroll
# 500    103     6.0       21                 The Armageddon Factor
# 501    103     6.0       22                 The Armageddon Factor
# 502    103     6.0       23                 The Armageddon Factor
# 503    103     6.0       24                 The Armageddon Factor
# 504    103     6.0       25                 The Armageddon Factor
# 505    103     6.0       26                 The Armageddon Factor
# 506    104     1.0        1                 Destiny of the Daleks
# 507    104     1.0        2                 Destiny of the Daleks
# 508    104     1.0        3                 Destiny of the Daleks
# 509    104     1.0        4                 Destiny of the Daleks
# 510    105     2.0        5                         City of Death
# 511    105     2.0        6                         City of Death
# 512    105     2.0        7                         City of Death
# 513    105     2.0        8                         City of Death
# 514    106     3.0        9             The Creature from the Pit
# 515    106     3.0       10             The Creature from the Pit
# 516    106     3.0       11             The Creature from the Pit
# 517    106     3.0       12             The Creature from the Pit
# 518    107     4.0       13                     Nightmare of Eden
# 519    107     4.0       14                     Nightmare of Eden
# 520    107     4.0       15                     Nightmare of Eden
# 521    107     4.0       16                     Nightmare of Eden
# 522    108     5.0       17                    The Horns of Nimon
# 523    108     5.0       18                    The Horns of Nimon
# 524    108     5.0       19                    The Horns of Nimon
# 525    108     5.0       20                    The Horns of Nimon
# 526    109     1.0        1                      The Leisure Hive
# 527    109     1.0        2                      The Leisure Hive
# 528    109     1.0        3                      The Leisure Hive
# 529    109     1.0        4                      The Leisure Hive
# 530    110     2.0        5                                Meglos
# 531    110     2.0        6                                Meglos
# 532    110     2.0        7                                Meglos
# 533    110     2.0        8                                Meglos
# 534    111     3.0        9                           Full Circle
# 535    111     3.0       10                           Full Circle
# 536    111     3.0       11                           Full Circle
# 537    111     3.0       12                           Full Circle
# 538    112     4.0       13                        State of Decay
# 539    112     4.0       14                        State of Decay
# 540    112     4.0       15                        State of Decay
# 541    112     4.0       16                        State of Decay
# 542    113     5.0       17                        Warriors' Gate
# 543    113     5.0       18                        Warriors' Gate
# 544    113     5.0       19                        Warriors' Gate
# 545    113     5.0       20                        Warriors' Gate
# 546    114     6.0       21                  The Keeper of Traken
# 547    114     6.0       22                  The Keeper of Traken
# 548    114     6.0       23                  The Keeper of Traken
# 549    114     6.0       24                  The Keeper of Traken
# 550    115     7.0       25                             Logopolis
# 551    115     7.0       26                             Logopolis
# 552    115     7.0       27                             Logopolis
# 553    115     7.0       28                             Logopolis
# 554    116     1.0        1                           Castrovalva
# 555    116     1.0        2                           Castrovalva
# 556    116     1.0        3                           Castrovalva
# 557    116     1.0        4                           Castrovalva
# 558    117     2.0        5                      Four to Doomsday
# 559    117     2.0        6                      Four to Doomsday
# 560    117     2.0        7                      Four to Doomsday
# 561    117     2.0        8                      Four to Doomsday
# 562    118     3.0        9                                 Kinda
# 563    118     3.0       10                                 Kinda
# 564    118     3.0       11                                 Kinda
# 565    118     3.0       12                                 Kinda
# 566    119     4.0       13                        The Visitation
# 567    119     4.0       14                        The Visitation
# 568    119     4.0       15                        The Visitation
# 569    119     4.0       16                        The Visitation
# 570    120     5.0       17                          Black Orchid
# 571    120     5.0       18                          Black Orchid
# 572    121     6.0       19                            Earthshock
# 573    121     6.0       20                            Earthshock
# 574    121     6.0       21                            Earthshock
# 575    121     6.0       22                            Earthshock
# 576    122     7.0       23                           Time-Flight
# 577    122     7.0       24                           Time-Flight
# 578    122     7.0       25                           Time-Flight
# 579    122     7.0       26                           Time-Flight
# 580    123     1.0        1                       Arc of Infinity
# 581    123     1.0        2                       Arc of Infinity
# 582    123     1.0        3                       Arc of Infinity
# 583    123     1.0        4                       Arc of Infinity
# 584    124     2.0        5                            Snakedance
# 585    124     2.0        6                            Snakedance
# 586    124     2.0        7                            Snakedance
# 587    124     2.0        8                            Snakedance
# 588    125     3.0        9                        Mawdryn Undead
# 589    125     3.0       10                        Mawdryn Undead
# 590    125     3.0       11                        Mawdryn Undead
# 591    125     3.0       12                        Mawdryn Undead
# 592    126     4.0       13                              Terminus
# 593    126     4.0       14                              Terminus
# 594    126     4.0       15                              Terminus
# 595    126     4.0       16                              Terminus
# 596    127     5.0       17                         Enlightenment
# 597    127     5.0       18                         Enlightenment
# 598    127     5.0       19                         Enlightenment
# 599    127     5.0       20                         Enlightenment
# 600    128     6.0       21                     The King's Demons
# 601    128     6.0       22                     The King's Demons
# 602    129     6.0       23                      The Five Doctors
# 603    130     1.0        1                  Warriors of the Deep
# 604    130     1.0        2                  Warriors of the Deep
# 605    130     1.0        3                  Warriors of the Deep
# 606    130     1.0        4                  Warriors of the Deep
# 607    131     2.0        5                         The Awakening
# 608    131     2.0        6                         The Awakening
# 609    132     3.0        7                              Frontios
# 610    132     3.0        8                              Frontios
# 611    132     3.0        9                              Frontios
# 612    132     3.0       10                              Frontios
# 613    133     4.0       11            Resurrection of the Daleks
# 614    133     4.0       12            Resurrection of the Daleks
# 615    134     5.0       13                        Planet of Fire
# 616    134     5.0       14                        Planet of Fire
# 617    134     5.0       15                        Planet of Fire
# 618    134     5.0       16                        Planet of Fire
# 619    135     6.0       17                The Caves of Androzani
# 620    135     6.0       18                The Caves of Androzani
# 621    135     6.0       19                The Caves of Androzani
# 622    135     6.0       20                The Caves of Androzani
# 623    136     7.0       21                      The Twin Dilemma
# 624    136     7.0       22                      The Twin Dilemma
# 625    136     7.0       23                      The Twin Dilemma
# 626    136     7.0       24                      The Twin Dilemma
# 627    137     1.0        1                Attack of the Cybermen
# 628    137     1.0        2                Attack of the Cybermen
# 629    138     2.0        3                    Vengeance on Varos
# 630    138     2.0        4                    Vengeance on Varos
# 631    139     3.0        5                  The Mark of the Rani
# 632    139     3.0        6                  The Mark of the Rani
# 633    140     4.0        7                       The Two Doctors
# 634    140     4.0        8                       The Two Doctors
# 635    140     4.0        9                       The Two Doctors
# 636    141     5.0       10                              Timelash
# 637    141     5.0       11                              Timelash
# 638    142     6.0       12              Revelation of the Daleks
# 639    142     6.0       13              Revelation of the Daleks
# 640    143     1.0        1                 The Mysterious Planet
# 641    143     1.0        2                 The Mysterious Planet
# 642    143     1.0        3                 The Mysterious Planet
# 643    143     1.0        4                 The Mysterious Planet
# 644    143     2.0        5                              Mindwarp
# 645    143     2.0        6                              Mindwarp
# 646    143     2.0        7                              Mindwarp
# 647    143     2.0        8                              Mindwarp
# 648    143     3.0        9                Terror of the Vervoids
# 649    143     3.0       10                Terror of the Vervoids
# 650    143     3.0       11                Terror of the Vervoids
# 651    143     3.0       12                Terror of the Vervoids
# 652    143     4.0       13                      The Ultimate Foe
# 653    143     4.0       14                      The Ultimate Foe
# 654    144     1.0        1                     Time and the Rani
# 655    144     1.0        2                     Time and the Rani
# 656    144     1.0        3                     Time and the Rani
# 657    144     1.0        4                     Time and the Rani
# 658    145     2.0        5                       Paradise Towers
# 659    145     2.0        6                       Paradise Towers
# 660    145     2.0        7                       Paradise Towers
# 661    145     2.0        8                       Paradise Towers
# 662    146     3.0        9               Delta and the Bannermen
# 663    146     3.0       10               Delta and the Bannermen
# 664    146     3.0       11               Delta and the Bannermen
# 665    147     4.0       12                            Dragonfire
# 666    147     4.0       13                            Dragonfire
# 667    147     4.0       14                            Dragonfire
# 668    148     1.0        1             Remembrance of the Daleks
# 669    148     1.0        2             Remembrance of the Daleks
# 670    148     1.0        3             Remembrance of the Daleks
# 671    148     1.0        4             Remembrance of the Daleks
# 672    149     2.0        5                  The Happiness Patrol
# 673    149     2.0        6                  The Happiness Patrol
# 674    149     2.0        7                  The Happiness Patrol
# 675    150     3.0        8                        Silver Nemesis
# 676    150     3.0        9                        Silver Nemesis
# 677    150     3.0       10                        Silver Nemesis
# 678    151     4.0       11       The Greatest Show in the Galaxy
# 679    151     4.0       12       The Greatest Show in the Galaxy
# 680    151     4.0       13       The Greatest Show in the Galaxy
# 681    151     4.0       14       The Greatest Show in the Galaxy
# 682    152     1.0        1                           Battlefield
# 683    152     1.0        2                           Battlefield
# 684    152     1.0        3                           Battlefield
# 685    152     1.0        4                           Battlefield
# 686    153     2.0        5                           Ghost Light
# 687    153     2.0        6                           Ghost Light
# 688    153     2.0        7                           Ghost Light
# 689    154     3.0        8                   The Curse of Fenric
# 690    154     3.0        9                   The Curse of Fenric
# 691    154     3.0       10                   The Curse of Fenric
# 692    154     3.0       11                   The Curse of Fenric
# 693    155     4.0       12                              Survival
# 694    155     4.0       13                              Survival
# ...
# 311            Jon Pertwee
# 312            Jon Pertwee
# 313            Jon Pertwee
# 314            Jon Pertwee
# 315            Jon Pertwee
# 316            Jon Pertwee
# 317            Jon Pertwee
# 318            Jon Pertwee
# 319            Jon Pertwee
# 320            Jon Pertwee
# 321            Jon Pertwee
# 322            Jon Pertwee
# 323            Jon Pertwee
# 324            Jon Pertwee
# 325            Jon Pertwee
# 326            Jon Pertwee
# 327            Jon Pertwee
# 328            Jon Pertwee
# 329            Jon Pertwee
# 330            Jon Pertwee
# 331            Jon Pertwee
# 332            Jon Pertwee
# 333            Jon Pertwee
# 334            Jon Pertwee
# 335            Jon Pertwee
# 336            Jon Pertwee
# 337            Jon Pertwee
# 338            Jon Pertwee
# 339            Jon Pertwee
# 340            Jon Pertwee
# 341            Jon Pertwee
# 342            Jon Pertwee
# 744          David Tennant
# 745          David Tennant
# 746          David Tennant
# 747          David Tennant
# 748          David Tennant
# 749          David Tennant
# 750          David Tennant
# 751          David Tennant
# 752          David Tennant
# 753          David Tennant
# 754          David Tennant
# 755          David Tennant
# 756             Matt Smith
# 757             Matt Smith
# 758             Matt Smith
# 759             Matt Smith
# 760             Matt Smith
# 761             Matt Smith
# 762             Matt Smith
# 763             Matt Smith
# 764             Matt Smith
# 765             Matt Smith
# 766             Matt Smith
# 767             Matt Smith
# 768             Matt Smith
# 769             Matt Smith
# 770             Matt Smith
# 771             Matt Smith
# 772             Matt Smith
# 773             Matt Smith
# 774             Matt Smith
# 775             Matt Smith
# 776             Matt Smith
# 777             Matt Smith
# 778             Matt Smith
# 779             Matt Smith
# 780             Matt Smith
# 781             Matt Smith
# 782             Matt Smith
# 783             Matt Smith
# 784             Matt Smith
# 785             Matt Smith
# 786             Matt Smith
# 787             Matt Smith
# 788             Matt Smith
# 789             Matt Smith
# 790             Matt Smith
# 791             Matt Smith
# 792             Matt Smith
# 793             Matt Smith
# 794             Matt Smith
# 795             Matt Smith
# 796             Matt Smith
# 797             Matt Smith
# 798             Matt Smith
# 799             Matt Smith
# 800          Peter Capaldi
# 801          Peter Capaldi
# 802          Peter Capaldi
# 803          Peter Capaldi
# 804          Peter Capaldi
# 805          Peter Capaldi
# 806          Peter Capaldi
# 807          Peter Capaldi
# 808          Peter Capaldi
# 809          Peter Capaldi
# 810          Peter Capaldi
# 811          Peter Capaldi
# 812          Peter Capaldi
# 813          Peter Capaldi
# 814          Peter Capaldi
# 815          Peter Capaldi
# 816          Peter Capaldi
# 817          Peter Capaldi
# 818          Peter Capaldi
# 819          Peter Capaldi
# 820          Peter Capaldi
# 821          Peter Capaldi
# 822          Peter Capaldi
# 823          Peter Capaldi
# 824          Peter Capaldi
# 825          Peter Capaldi
# 826          Peter Capaldi
# 827          Peter Capaldi
# 828          Peter Capaldi
# 829          Peter Capaldi
# 830          Peter Capaldi
# 831          Peter Capaldi
# 832          Peter Capaldi
# 833          Peter Capaldi
# 834          Peter Capaldi
# 835          Peter Capaldi
# 836          Peter Capaldi
# 837          Peter Capaldi
# 838          Peter Capaldi
# 839          Peter Capaldi
# 840        Jodie Whittaker
# 841        Jodie Whittaker
# 842        Jodie Whittaker
# 843        Jodie Whittaker
# 844        Jodie Whittaker
# 845        Jodie Whittaker
# 846        Jodie Whittaker
# 847        Jodie Whittaker
# 848        Jodie Whittaker
# 849        Jodie Whittaker
# 850        Jodie Whittaker
# 851        Jodie Whittaker
# 852        Jodie Whittaker
# 853        Jodie Whittaker
# 854        Jodie Whittaker
# 855        Jodie Whittaker
# 856        Jodie Whittaker
# 857        Jodie Whittaker
# 858        Jodie Whittaker
# 859        Jodie Whittaker
# 860        Jodie Whittaker
# 861        Jodie Whittaker

# %% [markdown]
# #### Saving dataframe into a CSV.

# %%
dr_who.to_csv('dr_who_dataset.csv')

# %% [markdown]
# <h4>Author:  <a href="https://www.linkedin.com/in/sergey-khegay/">Sergey Khegay</a></h4>
